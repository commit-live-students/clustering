# %% [markdown]
# # Review
#
#
# ## Miscellaneous
#
# 1. What is Feature Selection?
# 2. On an average, if we consider all possible datasets for binary classification task, which of the following algorithm is likely to do the best?
#     1. Random Coin-toss
#     2. Logistic Regression
#     3. Random Forest Classifier
# 3. What is supervised machine learning?
#
# ---
#
# ## Linear Regression
#
# 1. What is Linear Regression?
# 2. How do we handle it in Linear Regression if our dataset is not linearly separable?
# 3. How do we handle the problem of Multicollinearity in Linear Regression?
# 4. Why do we need regularization? When is it useful?
# 5. What is the difference between Ridge and Lasso regression?
#
# ---
#
# ## Logistic Regression
# 1. What is Logistic Regression? How is it different from Liner Regression?
# 2. What is concordance for a logistic regression model? Is a higher value of concordance better? [Link 1](https://www.quora.com/How-do-I-interpret-concordance-in-Logistic-Regression), [Link 2](https://discuss.analyticsvidhya.com/t/is-concordance-the-best-way-to-predict-logistic-regression-model-reliability/267/2)
#
# ---
#
# ## Hyperparameter Tuning
#
# 1. What is the difference between parameter and hyperparameter?
# 2. What is hyperparameter tuning? Why do we do it? Give an example of an algorithm that needs it and an algorithm that doesn't need it.
# 3. Name at least two hyperparameter tuning strategies. Which one is better?
#
# ---
#
# ## Cross-validation
#
# 1. What is k-fold cross-validation?
# 2. Why do we do cross-validation?
# 3. In k-fold cross-validation. What should be the values of k?
#
# ---
#
# ## Support Vector Machines
# 1. What are Support Vector Machines?
# 2. What is the kernel trick in SVMs?
# 3. Which kernels are suitable for datasets that are not linearly separable?
#
# ---
#
# ## Decision Tree
# 1. What is a Decision Tree?
# 2. What are the problems with Decision Trees?
#
# ---
#
# ## Random Forest
# 1. What are Random Forest?
# 2. How do we build Random Forests out of Decision Trees?
#
# ---
#
# ## Unsupervised Machine Learning
# 1. What is unsupervised machine learning?
# 2. What is PCA? What is it good for?
# 3. How do we determine the number of PCs to be selected?
# 4. If your feature-matrix is sparse, what algorithm will you use for dimensionality reduction? Give an example of a dataset where the feature-matrix is likely to be sparse.
#
# ---
#
# ## Natural Language Processing
# 1. What is tokenization?
# 2. What is stop-word removal? Why do we do it?
# 3. What is stemming? Why do we do it?
# 15. What is the bag-of-words model?
#
# ---
